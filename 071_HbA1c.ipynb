# %% [markdown]
# <a href="https://colab.research.google.com/github/BooEiEi/project/blob/main/071_HbA1c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #นำเข้า pandas แทนที่ด้วย pd
import os# os ใช้จัดการกับไฟล์ ว่าอยู่ที่ไหน
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive #นำเข้าข้อมูลจาก drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/project'# ชี้ dirve ที่เราต้องการ
import missingno as mno
import missingno as msno
from sklearn import linear_model
# %matplotlib inline
import matplotlib
import sklearn 
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_squared_error
import time
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv(os.path.join(path, 'DFforCreateNaN.csv'))
data = data.drop(['Unnamed: 0'], axis=1)
data
# Out:
#      Sex  AgeSYear  Weight  Height   BMI  Systolic  Diastolic  HeartRate  \
# 0      2      57.0    47.4   153.0  20.2     114.0       75.0       69.0
# 1      2      24.0    53.2   157.0  21.6     103.0       69.0       78.0
# 2      2      62.0    54.4   165.0  20.0      95.0       75.0       83.0
# 3      2      35.0    56.3   161.0  21.7      95.0       57.0       72.0
# 4      1      46.0    72.3   170.0  25.0     133.0       77.0      107.0
# ..   ...       ...     ...     ...   ...       ...        ...        ...
# 148    1      60.0    72.0   170.0  24.9     131.0       74.0       69.0
# 149    1      58.0    62.0   168.0  22.0     103.0       76.0       72.0
# 150    2      42.0    55.5   165.0  20.4     102.0       52.0       77.0
# 151    2      61.0    61.8   159.0  24.4     117.0       60.0       72.0
# 152    2      31.0    58.2   169.0  20.4     108.0       69.0       73.0
#
#       SMM  Fat Mass  ...  003_Creatinine  004_Uric Acid  005_Cholesterol  \
# 0    19.3      12.5  ...             1.0            5.0            176.0
# 1    21.3      14.6  ...             0.8            5.2            159.0
# 2    21.6      15.2  ...             0.7            4.1            230.0
# 3    22.5      15.4  ...             0.6            5.0            198.0
# 4    29.2      19.0  ...             0.9            6.9            194.0
# ..    ...       ...  ...             ...            ...              ...
# 148  30.5      13.8  ...             0.9            6.9            182.0
# 149  27.8      11.9  ...             1.0            6.8            191.0
# 150  22.9      14.1  ...             0.8            4.7            212.0
# 151  23.4      19.2  ...             0.8            5.1            235.0
# 152  25.0      13.0  ...             0.7            4.3            200.0
#
#      006_Triglyceride  008_HDL-C  009_LDL  010_AST  012_ALT  \
# 0                51.0       72.0     94.0     16.0     16.0
# 1                45.0       52.0     98.0     13.0     17.0
# 2                94.0       61.0    151.0     18.0     31.0
# 3                47.0       68.0    120.0     16.0     20.0
# 4                63.0       60.0    122.0     15.0     19.0
# ..                ...        ...      ...      ...      ...
# 148             179.0       39.0    107.0     36.0     31.0
# 149              62.0       47.0    132.0     16.0     33.0
# 150              68.0       63.0    135.0     11.0     16.0
# 151              66.0       56.0    166.0     15.0     23.0
# 152              44.0       56.0    135.0     14.0     21.0
#
#      013_Alkaline Phos  071_HbA1c
# 0                 62.0        5.1
# 1                 50.0        5.4
# 2                 76.0        5.6
# 3                 35.0        5.1
# 4                 69.0        5.2
# ..                 ...        ...
# 148               79.0        6.5
# 149               42.0        6.8
# 150               33.0        4.8
# 151               44.0        5.4
# 152               31.0        4.7
#
# [153 rows x 26 columns]

# %% [markdown]
# # 10 % random nan

# %%
for i in range(1,1001):
  globals()[f'HbA1c1{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*10/100)) 
  index_nan = np.random.choice(globals()[f'HbA1c1{i}']['071_HbA1c'].size, n, replace=False)
  globals()[f'HbA1c1{i}']['071_HbA1c'].ravel()[index_nan] = np.nan

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean10_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean10_{i}'] = mean10_imputer.fit_transform(globals()[f'HbA1c1{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN10_{i}'] = mean_squared_error(data, globals()[f'imputed_mean10_{i}']) # for loop mean_squared_error
t_end = time.time()
t10_MEAN= (t_end- t_start)

# %%
t_start = time.time()
mse_mean10_total = 0 
MSE_MEAN10_1001 = 0
for i in range(1,1001):
  mse_mean10_total = mse_mean10_total + globals()[f'MSE_MEAN10_{i}']
AMSE_HbA1c1_mean = mse_mean10_total/1000
print(f'AMSE_HbA1c1_mean = {AMSE_HbA1c1_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c1_mean = 0.006941468036392978
# เวลาที่ใช้ในการประมวลผล 0.00099945068359375 วินาที
# เวลาที่ใช้ในการประมวลผล 1.6657511393229165e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting missingpy
#   Downloading missingpy-0.2.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 3.0 MB/s
# Installing collected packages: missingpy
# Successfully installed missingpy-0.2.0

# %%
t_start = time.time()
MF10_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf10_{i}'] = MF10_imputer.fit_transform(globals()[f'HbA1c1{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF10_{i}'] = mean_squared_error(data, globals()[f'imputed_mf10_{i}']) # for loop mean_squared_error
t_end = time.time()
t10_MF= (t_end- t_start)

# %%
t_start = time.time()
mse_mf10_total = 0 
MSE_MF10_1001 = 0
for i in range(1,1001):
  mse_mf10_total = mse_mf10_total + globals()[f'MSE_MF10_{i}']
AMSE_HbA1c1_mf = mse_mf10_total/1000
print(f'AMSE_HbA1c1_mf = {AMSE_HbA1c1_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c1_mf = 0.006577486963549519
# เวลาที่ใช้ในการประมวลผล 0.0009856224060058594 วินาที
# เวลาที่ใช้ในการประมวลผล 1.6427040100097658e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN10_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN10_{i}'] = KNN10_imputer.fit_transform(globals()[f'HbA1c1{i}'].copy())
  globals()[f'MSE_KNN10_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN10_{i}'])
t_end = time.time()
t10_KNN= (t_end- t_start)

# %%
t_start = time.time()
mse_knn10_total = 0 
MSE_KNN10_1001 = 0
for i in range(1,1001):
  mse_knn10_total = mse_knn10_total + globals()[f'MSE_KNN10_{i}']
AMSE_HbA1c1_knn = mse_knn10_total/1000
print(f'AMSE_HbA1c1_knn = {AMSE_HbA1c1_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c1_knn = 0.007122158326350488
# เวลาที่ใช้ในการประมวลผล 0.0010297298431396484 วินาที
# เวลาที่ใช้ในการประมวลผล 1.7162164052327474e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr10_{i}'] = imp.fit_transform(globals()[f'HbA1c1{i}'].copy())
  globals()[f'MSE_lr10_{i}'] = mean_squared_error(data, globals()[f'imputed_lr10_{i}'])
t_end = time.time()
t10_LR= (t_end- t_start)

# %%
t_start = time.time()
mse_lr10_total = 0 
MSE_lr10_1001 = 0
for i in range(1,1001):
  mse_lr10_total = mse_lr10_total + globals()[f'MSE_lr10_{i}']
AMSE_HbA1c1_lr = mse_lr10_total/1000
print(f'AMSE_HbA1c1_lr = {AMSE_HbA1c1_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c1_lr = 0.00992835750681835
# เวลาที่ใช้ในการประมวลผล 0.0011262893676757812 วินาที
# เวลาที่ใช้ในการประมวลผล 1.877148946126302e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm10_{i}'] = svm_svr.fit_transform(globals()[f'HbA1c1{i}'].copy())
  globals()[f'MSE_svm10_{i}'] = mean_squared_error(data, globals()[f'imputed_svm10_{i}'])
t_end = time.time()
t10_SVM= (t_end- t_start)

# %%
t_start = time.time()
mse_svm10_total = 0 
MSE_svm10_1001 = 0
for i in range(1,1001):
  mse_svm10_total = mse_svm10_total + globals()[f'MSE_svm10_{i}']
AMSE_HbA1c1_svm = mse_svm10_total/1000
print(f'AMSE_HbA1c1_svm = {AMSE_HbA1c1_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c1_svm = 0.006830879803322701
# เวลาที่ใช้ในการประมวลผล 0.0011739730834960938 วินาที
# เวลาที่ใช้ในการประมวลผล 1.9566218058268228e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting impyute
#   Downloading impyute-0.0.8-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)
# Installing collected packages: impyute
# Successfully installed impyute-0.0.8

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy10_{i}'] = impy.em(globals()[f'HbA1c1{i}'].values.copy())
  globals()[f'MSE_impy10_{i}'] = mean_squared_error(data, globals()[f'imputed_impy10_{i}'])
t_end = time.time()
t10_EM= (t_end- t_start)

# %%
t_start = time.time()
mse_impy10_total = 0 
MSE_impy10_1001 = 0
for i in range(1,1001):
  mse_impy10_total = mse_impy10_total + globals()[f'MSE_impy10_{i}']
AMSE_HbA1c1_impy = mse_impy10_total/1000
print(f'AMSE_HbA1c1_impy = {AMSE_HbA1c1_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c1_impy = 0.013335867602873143
# เวลาที่ใช้ในการประมวลผล 0.0007698535919189453 วินาที
# เวลาที่ใช้ในการประมวลผล 1.283089319864909e-05 นาที

# %% [markdown]
# # 20 % random nan

# %%
for i in range(1,1001):
  globals()[f'HbA1c2{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*20/100)) 
  index_nan = np.random.choice(globals()[f'HbA1c2{i}']['071_HbA1c'].size, n, replace=False)
  globals()[f'HbA1c2{i}']['071_HbA1c'].ravel()[index_nan] = np.nan

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean20_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean20_{i}'] = mean10_imputer.fit_transform(globals()[f'HbA1c2{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN20_{i}'] = mean_squared_error(data, globals()[f'imputed_mean20_{i}']) # for loop mean_squared_error
t_end = time.time()
t20_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean20_total = 0 
MSE_MEAN20_1001 = 0
for i in range(1,1001):
  mse_mean20_total = mse_mean20_total + globals()[f'MSE_MEAN20_{i}']
AMSE_HbA1c2_mean = mse_mean20_total/1000
print(f'AMSE_HbA1c2_mean = {AMSE_HbA1c2_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c2_mean = 0.014051448356601805
# เวลาที่ใช้ในการประมวลผล 0.0011165142059326172 วินาที
# เวลาที่ใช้ในการประมวลผล 1.8608570098876952e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF20_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf20_{i}'] = MF20_imputer.fit_transform(globals()[f'HbA1c2{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF20_{i}'] = mean_squared_error(data, globals()[f'imputed_mf20_{i}']) # for loop mean_squared_error
t_end = time.time()
t20_MF = (t_end- t_start)

# %%
t_start = time.time()
mse_mf20_total = 0 
MSE_MF20_1001 = 0
for i in range(1,1001):
  mse_mf20_total = mse_mf20_total + globals()[f'MSE_MF20_{i}']
AMSE_HbA1c2_mf = mse_mf20_total/1000
print(f'AMSE_HbA1c2_mf = {AMSE_HbA1c2_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c2_mf = 0.013472092477124182
# เวลาที่ใช้ในการประมวลผล 0.0011665821075439453 วินาที
# เวลาที่ใช้ในการประมวลผล 1.944303512573242e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN20_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN20_{i}'] = KNN10_imputer.fit_transform(globals()[f'HbA1c2{i}'].copy())
  globals()[f'MSE_KNN20_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN20_{i}'])
t_end = time.time()
t20_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn20_total = 0 
MSE_KNN20_1001 = 0
for i in range(1,1001):
  mse_knn20_total = mse_knn20_total + globals()[f'MSE_KNN20_{i}']
AMSE_HbA1c2_knn = mse_knn20_total/1000
print(f'AMSE_HbA1c2_knn = {AMSE_HbA1c2_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c2_knn = 0.0141687860566449
# เวลาที่ใช้ในการประมวลผล 0.0008742809295654297 วินาที
# เวลาที่ใช้ในการประมวลผล 1.4571348826090495e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp20 = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr20_{i}'] = imp20.fit_transform(globals()[f'HbA1c2{i}'].copy())
  globals()[f'MSE_lr20_{i}'] = mean_squared_error(data, globals()[f'imputed_lr20_{i}'])
t_end = time.time()
t20_LR = (t_end- t_start)

# %%
t_start = time.time()
mse_lr20_total = 0 
MSE_lr20_1001 = 0
for i in range(1,1001):
  mse_lr20_total = mse_lr20_total + globals()[f'MSE_lr20_{i}']
AMSE_HbA1c2_lr = mse_lr20_total/1000
print(f'AMSE_HbA1c2_lr = {AMSE_HbA1c2_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c2_lr = 0.02127519835557368
# เวลาที่ใช้ในการประมวลผล 0.0009396076202392578 วินาที
# เวลาที่ใช้ในการประมวลผล 1.566012700398763e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm20_{i}'] = svm_svr.fit_transform(globals()[f'HbA1c2{i}'].copy())
  globals()[f'MSE_svm20_{i}'] = mean_squared_error(data, globals()[f'imputed_svm20_{i}'])
t_end = time.time()
t20_SVM = (t_end- t_start)

# %%
t_start = time.time()
mse_svm20_total = 0 
MSE_svm20_1001 = 0
for i in range(1,1001):
  mse_svm20_total = mse_svm20_total + globals()[f'MSE_svm20_{i}']
AMSE_HbA1c2_svm = mse_svm20_total/1000
print(f'AMSE_HbA1c2_svm = {AMSE_HbA1c2_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c2_svm = 0.013772231583992512
# เวลาที่ใช้ในการประมวลผล 0.000934600830078125 วินาที
# เวลาที่ใช้ในการประมวลผล 1.5576680501302082e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy20_{i}'] = impy.em(globals()[f'HbA1c2{i}'].values.copy())
  globals()[f'MSE_impy20_{i}'] = mean_squared_error(data, globals()[f'imputed_impy20_{i}'])
t_end = time.time()
t20_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy20_total = 0 
MSE_impy20_1001 = 0
for i in range(1,1001):
  mse_impy20_total = mse_impy20_total + globals()[f'MSE_impy20_{i}']
AMSE_HbA1c2_impy = mse_impy20_total/1000
print(f'AMSE_HbA1c2_impy = {AMSE_HbA1c2_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c2_impy = 0.02616443419176357
# เวลาที่ใช้ในการประมวลผล 0.000904083251953125 วินาที
# เวลาที่ใช้ในการประมวลผล 1.506805419921875e-05 นาที

# %% [markdown]
# # 30 % random nan

# %%
for i in range(1,1001):
  globals()[f'HbA1c3{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*30/100)) 
  index_nan = np.random.choice(globals()[f'HbA1c3{i}']['071_HbA1c'].size, n, replace=False)
  globals()[f'HbA1c3{i}']['071_HbA1c'].ravel()[index_nan] = np.nan

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean30_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean30_{i}'] = mean30_imputer.fit_transform(globals()[f'HbA1c3{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN30_{i}'] = mean_squared_error(data, globals()[f'imputed_mean30_{i}']) # for loop mean_squared_error
t_end = time.time()
t30_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean30_total = 0 
MSE_MEAN30_1001 = 0
for i in range(1,1001):
  mse_mean30_total = mse_mean30_total + globals()[f'MSE_MEAN30_{i}']
AMSE_HbA1c3_mean = mse_mean30_total/1000
print(f'AMSE_HbA1c3_mean = {AMSE_HbA1c3_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c3_mean = 0.021101056689492848
# เวลาที่ใช้ในการประมวลผล 0.0011892318725585938 วินาที
# เวลาที่ใช้ในการประมวลผล 1.9820531209309897e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF30_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf30_{i}'] = MF30_imputer.fit_transform(globals()[f'HbA1c3{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF30_{i}'] = mean_squared_error(data, globals()[f'imputed_mf30_{i}']) # for loop mean_squared_error
t_end = time.time()
t30_MF = (t_end- t_start)

# %%
t_start = time.time()
mse_mf30_total = 0 
MSE_MF30_1001 = 0
for i in range(1,1001):
  mse_mf30_total = mse_mf30_total + globals()[f'MSE_MF30_{i}']
AMSE_HbA1c3_mf = mse_mf30_total/1000
print(f'AMSE_HbA1c3_mf = {AMSE_HbA1c3_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c3_mf = 0.02040262843916538
# เวลาที่ใช้ในการประมวลผล 0.001317739486694336 วินาที
# เวลาที่ใช้ในการประมวลผล 2.196232477823893e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN30_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN30_{i}'] = KNN30_imputer.fit_transform(globals()[f'HbA1c3{i}'].copy())
  globals()[f'MSE_KNN30_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN30_{i}'])
t_end = time.time()
t30_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn30_total = 0 
MSE_KNN30_1001 = 0
for i in range(1,1001):
  mse_knn30_total = mse_knn30_total + globals()[f'MSE_KNN30_{i}']
AMSE_HbA1c3_knn = mse_knn30_total/1000
print(f'AMSE_HbA1c3_knn = {AMSE_HbA1c3_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c3_knn = 0.02081475186861073
# เวลาที่ใช้ในการประมวลผล 0.001125335693359375 วินาที
# เวลาที่ใช้ในการประมวลผล 1.8755594889322918e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp30 = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr30_{i}'] = imp30.fit_transform(globals()[f'HbA1c3{i}'].copy())
  globals()[f'MSE_lr30_{i}'] = mean_squared_error(data, globals()[f'imputed_lr30_{i}'])
t_end = time.time()
t30_LR = (t_end- t_start)

# %%
t_start = time.time()
mse_lr30_total = 0 
MSE_lr30_1001 = 0
for i in range(1,1001):
  mse_lr30_total = mse_lr30_total + globals()[f'MSE_lr30_{i}']
AMSE_HbA1c3_lr = mse_lr30_total/1000
print(f'AMSE_HbA1c3_lr = {AMSE_HbA1c3_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c3_lr = 0.033861144484929544
# เวลาที่ใช้ในการประมวลผล 0.0009024143218994141 วินาที
# เวลาที่ใช้ในการประมวลผล 1.5040238698323568e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm30_{i}'] = svm_svr.fit_transform(globals()[f'HbA1c3{i}'].copy())
  globals()[f'MSE_svm30_{i}'] = mean_squared_error(data, globals()[f'imputed_svm30_{i}'])
t_end = time.time()
t30_SVM = (t_end- t_start)

# %%
t_start = time.time()
mse_svm30_total = 0 
MSE_svm30_1001 = 0
for i in range(1,1001):
  mse_svm30_total = mse_svm30_total + globals()[f'MSE_svm30_{i}']
AMSE_HbA1c3_svm = mse_svm30_total/1000
print(f'AMSE_HbA1c3_svm = {AMSE_HbA1c3_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c3_svm = 0.020707540756358712
# เวลาที่ใช้ในการประมวลผล 0.0011410713195800781 วินาที
# เวลาที่ใช้ในการประมวลผล 1.9017855326334635e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy30_{i}'] = impy.em(globals()[f'HbA1c3{i}'].values.copy())
  globals()[f'MSE_impy30_{i}'] = mean_squared_error(data, globals()[f'imputed_impy30_{i}'])
t_end = time.time()
t30_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy30_total = 0 
MSE_impy30_1001 = 0
for i in range(1,1001):
  mse_impy30_total = mse_impy30_total + globals()[f'MSE_impy30_{i}']
AMSE_HbA1c3_impy = mse_impy30_total/1000
print(f'AMSE_HbA1c3_impy = {AMSE_HbA1c3_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c3_impy = 0.04002879403372523
# เวลาที่ใช้ในการประมวลผล 0.0008871555328369141 วินาที
# เวลาที่ใช้ในการประมวลผล 1.47859255472819e-05 นาที

# %% [markdown]
# # 40 % random nan

# %%
for i in range(1,1001):
  globals()[f'HbA1c4{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*40/100)) 
  index_nan = np.random.choice(globals()[f'HbA1c4{i}']['071_HbA1c'].size, n, replace=False)
  globals()[f'HbA1c4{i}']['071_HbA1c'].ravel()[index_nan] = np.nan

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean40_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean40_{i}'] = mean40_imputer.fit_transform(globals()[f'HbA1c4{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN40_{i}'] = mean_squared_error(data, globals()[f'imputed_mean40_{i}']) # for loop mean_squared_error
t_end = time.time()
t40_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean40_total = 0 
MSE_MEAN40_1001 = 0
for i in range(1,1001):
  mse_mean40_total = mse_mean40_total + globals()[f'MSE_MEAN40_{i}']
AMSE_HbA1c4_mean = mse_mean40_total/1000
print(f'AMSE_HbA1c4_mean = {AMSE_HbA1c4_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c4_mean = 0.028491707872742408
# เวลาที่ใช้ในการประมวลผล 0.0009069442749023438 วินาที
# เวลาที่ใช้ในการประมวลผล 1.5115737915039062e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF40_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf40_{i}'] = MF40_imputer.fit_transform(globals()[f'HbA1c4{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF40_{i}'] = mean_squared_error(data, globals()[f'imputed_mf40_{i}']) # for loop mean_squared_error
t_end = time.time()
t40_MF = (t_end- t_start)

# %%
t_start = time.time()
mse_mf40_total = 0 
MSE_MF40_1001 = 0
for i in range(1,1001):
  mse_mf40_total = mse_mf40_total + globals()[f'MSE_MF40_{i}']
AMSE_HbA1c4_mf = mse_mf40_total/1000
print(f'AMSE_HbA1c4_mf = {AMSE_HbA1c4_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c4_mf = 0.028021392924585192
# เวลาที่ใช้ในการประมวลผล 0.0010972023010253906 วินาที
# เวลาที่ใช้ในการประมวลผล 1.8286705017089844e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN40_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN40_{i}'] = KNN40_imputer.fit_transform(globals()[f'HbA1c4{i}'].copy())
  globals()[f'MSE_KNN40_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN40_{i}'])
t_end = time.time()
t40_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn40_total = 0 
MSE_KNN40_1001 = 0
for i in range(1,1001):
  mse_knn40_total = mse_knn40_total + globals()[f'MSE_KNN40_{i}']
AMSE_HbA1c4_knn = mse_knn40_total/1000
print(f'AMSE_HbA1c4_knn = {AMSE_HbA1c4_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c4_knn = 0.027876062219987698
# เวลาที่ใช้ในการประมวลผล 0.0011262893676757812 วินาที
# เวลาที่ใช้ในการประมวลผล 1.877148946126302e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp40 = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr40_{i}'] = imp40.fit_transform(globals()[f'HbA1c4{i}'].copy())
  globals()[f'MSE_lr40_{i}'] = mean_squared_error(data, globals()[f'imputed_lr40_{i}'])
t_end = time.time()
t40_LR = (t_end- t_start)

# %%
t_start = time.time()
mse_lr40_total = 0 
MSE_lr40_1001 = 0
for i in range(1,1001):
  mse_lr40_total = mse_lr40_total + globals()[f'MSE_lr40_{i}']
AMSE_HbA1c4_lr = mse_lr40_total/1000
print(f'AMSE_HbA1c4_lr = {AMSE_HbA1c4_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c4_lr = 0.05234027115404965
# เวลาที่ใช้ในการประมวลผล 0.0010592937469482422 วินาที
# เวลาที่ใช้ในการประมวลผล 1.7654895782470702e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm40_{i}'] = svm_svr.fit_transform(globals()[f'HbA1c4{i}'].copy())
  globals()[f'MSE_svm40_{i}'] = mean_squared_error(data, globals()[f'imputed_svm40_{i}'])
t_end = time.time()
t40_SVM = (t_end- t_start)

# %%
t_start = time.time()
mse_svm40_total = 0 
MSE_svm40_1001 = 0
for i in range(1,1001):
  mse_svm40_total = mse_svm40_total + globals()[f'MSE_svm40_{i}']
AMSE_HbA1c4_svm = mse_svm40_total/1000
print(f'AMSE_HbA1c4_svm = {AMSE_HbA1c4_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c4_svm = 0.02800841706372047
# เวลาที่ใช้ในการประมวลผล 0.001241922378540039 วินาที
# เวลาที่ใช้ในการประมวลผล 2.069870630900065e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy40_{i}'] = impy.em(globals()[f'HbA1c4{i}'].values.copy())
  globals()[f'MSE_impy40_{i}'] = mean_squared_error(data, globals()[f'imputed_impy40_{i}'])
t_end = time.time()
t40_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy40_total = 0 
MSE_impy40_1001 = 0
for i in range(1,1001):
  mse_impy40_total = mse_impy40_total + globals()[f'MSE_impy40_{i}']
AMSE_HbA1c4_impy = mse_impy40_total/1000
print(f'AMSE_HbA1c4_impy = {AMSE_HbA1c4_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c4_impy = 0.05457640613392037
# เวลาที่ใช้ในการประมวลผล 0.0009894371032714844 วินาที
# เวลาที่ใช้ในการประมวลผล 1.6490618387858074e-05 นาที

# %% [markdown]
# # 50 % random nan

# %%
for i in range(1,1001):
  globals()[f'HbA1c5{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*50/100)) 
  index_nan = np.random.choice(globals()[f'HbA1c5{i}']['071_HbA1c'].size, n, replace=False)
  globals()[f'HbA1c5{i}']['071_HbA1c'].ravel()[index_nan] = np.nan

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean50_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean50_{i}'] = mean50_imputer.fit_transform(globals()[f'HbA1c5{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN50_{i}'] = mean_squared_error(data, globals()[f'imputed_mean50_{i}']) # for loop mean_squared_error
t_end = time.time()
t50_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean50_total = 0 
MSE_MEAN50_1001 = 0
for i in range(1,1001):
  mse_mean50_total = mse_mean50_total + globals()[f'MSE_MEAN50_{i}']
AMSE_HbA1c5_mean = mse_mean50_total/1000
print(f'AMSE_HbA1c5_mean = {AMSE_HbA1c5_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c5_mean = 0.03550300224645907
# เวลาที่ใช้ในการประมวลผล 0.0009686946868896484 วินาที
# เวลาที่ใช้ในการประมวลผล 1.6144911448160808e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF50_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf50_{i}'] = MF50_imputer.fit_transform(globals()[f'HbA1c5{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF50_{i}'] = mean_squared_error(data, globals()[f'imputed_mf50_{i}']) # for loop mean_squared_error
t_end = time.time()
t50_MF = (t_end- t_start)

# %%
t_start = time.time()
mse_mf50_total = 0 
MSE_MF50_1001 = 0
for i in range(0,1001):
  mse_mf50_total = mse_mf50_total + globals()[f'MSE_MF50_{i+1}']
AMSE_HbA1c5_mf = mse_mf50_total/1000
print(f'AMSE_HbA1c5_mf = {AMSE_HbA1c5_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c5_mf = 0.03546127009225742
# เวลาที่ใช้ในการประมวลผล 0.0011866092681884766 วินาที
# เวลาที่ใช้ในการประมวลผล 1.977682113647461e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN50_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN50_{i}'] = KNN30_imputer.fit_transform(globals()[f'HbA1c5{i}'].copy())
  globals()[f'MSE_KNN50_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN50_{i}'])
t_end = time.time()
t50_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn50_total = 0 
MSE_KNN50_1001 = 0
for i in range(1,1001):
  mse_knn50_total = mse_knn30_total + globals()[f'MSE_KNN50_{i}']
AMSE_HbA1c5_knn = mse_knn30_total/1000
print(f'AMSE_HbA1c5_knn = {AMSE_HbA1c5_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c5_knn = 0.02081475186861073
# เวลาที่ใช้ในการประมวลผล 0.0031087398529052734 วินาที
# เวลาที่ใช้ในการประมวลผล 5.1812330881754556e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp50 = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr50_{i}'] = imp50.fit_transform(globals()[f'HbA1c5{i}'].copy())
  globals()[f'MSE_lr50_{i}'] = mean_squared_error(data, globals()[f'imputed_lr50_{i}'])
t_end = time.time()
t50_LR = (t_end- t_start)

# %%
t_start = time.time()
mse_lr50_total = 0 
MSE_lr50_1001 = 0
for i in range(1,1001):
  mse_lr50_total = mse_lr50_total + globals()[f'MSE_lr50_{i}']
AMSE_HbA1c5_lr = mse_lr50_total/1000
print(f'AMSE_HbA1c5_lr = {AMSE_HbA1c5_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c5_lr = 0.07709777764307253
# เวลาที่ใช้ในการประมวลผล 0.0009856224060058594 วินาที
# เวลาที่ใช้ในการประมวลผล 1.6427040100097658e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm50_{i}'] = svm_svr.fit_transform(globals()[f'HbA1c5{i}'].copy())
  globals()[f'MSE_svm50_{i}'] = mean_squared_error(data, globals()[f'imputed_svm50_{i}'])
t_end = time.time()
t50_SVM = (t_end- t_start)
# Out:
# Streaming output truncated to the last 5000 lines.
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.2003343509781432, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9603845375899027, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.40764018638327304, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6717294864035148, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5053013006305012, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8835869014882975, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8198109812190824, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.8187515977154058, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7519430217445446, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.1437226473563644, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6726003565387781, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7577330897856216, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.769135879840757, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.47072646108224436, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6860009836720602, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.48796604746914163, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7898879054175563, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7559670980779529, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7507030912794823, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.32858021707756624, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.6384459087765713, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8877160418317764, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.524099612822102, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.097442542077161, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6947993568654081, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5961269348478595, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7538685607770992, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5338242390860843, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7036851801946691, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.4671745940968952, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.2952606354075291, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.49856240399033513, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.819561922886213, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9885534595627821, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.4702511855170757, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8433933991408162, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6629485403670108, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5200996016153621, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.502473959599036, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.8314160511511828, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.1303174124606477, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6809829120841977, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.6489428386083187, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.118822468054364, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5879975071363717, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6324667192996287, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.14
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7501898624386731, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7602219279751781, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.699891977165211, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6875308246335514, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.8813947390908154, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.618991161367771, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7870621017724648, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5415356380863745, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0954270637784846, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7111085951679135, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.533595015474801, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.37950660430894523, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.5748185938329486, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.3907296746823903, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8000935657121326, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.40108683686474933, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8183979834879453, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.5836753021002092, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6061922937449538, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7053529146921438, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.1298571304202945, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.45405973851230375, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.485288248255924, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.601685911663612, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.47227592150381525, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.4465922069033388, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.44728428997445846, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.41734050384666777, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7178938911261614, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6420829199497469, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.62592350274811, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.66932373950777, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6421956322814708, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.9522291186342002, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.1981047042470268, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5504298078351484, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.800611571708421, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.2408918281728534, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.5334578109547339, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7905070616459202, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5932088021939519, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.5918758204291077, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5226616788431624, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5881289845582636, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8903897595293193, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6029601065324526, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7842421014608512, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.038974013280403, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.14
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.3227651111848786, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.587091451128841, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7231243244314367, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9893294167685669, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7350552900944454, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9084521909482062, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.41454345722926966, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5075782502334567, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9655380670539069, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.6352861772277194, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7880510655496655, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.20536543923131045, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9984300480272799, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6182342392259148, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.120227493806798, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.8907053982016171, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7519095655999619, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7558666016448017, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.40301419675165473, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.0247970924855707, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5606865929641343, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7819528805703051, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7829896433837105, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.49807738687139924, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.4655671101336054, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6965978313517436, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7619962780061993, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.648258726151691, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6912061022618978, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.985908321866777, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.574933247247503, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8221002705952056, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.6008177001236188, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6464492653096823, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# ...
# [IterativeImputer] Change: 0.7195046074152485, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.4656087708609471, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.14
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5720040234788533, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.5381871150895483, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8843268695484863, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9626195209506916, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7844868931946891, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5095485252791097, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.6222637176013821, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7112648782107271, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.14
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.761816405387095, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.0135721587683593, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.039140677063303, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6098074244290812, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.8570286628976653, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8722193298094814, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8545376539232379, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6412816195418776, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6286291775340551, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.9134998968944368, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6476964353362078, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5682466570891709, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7470688576499676, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6353732521598614, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8361812112899356, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6940578511846027, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.1558948020805495, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7025525304269244, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8059427607670262, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8359082684831227, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7485847187093624, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6432878596320721, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.4930536558186507, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8370165911033682, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5641134571868873, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7910237938953406, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.37328270554153065, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6783676033650439, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.884295455088818, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5487255597318006, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.417249218946127, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7444709429844316, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8301880422898638, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.

# %%
t_start = time.time()
mse_svm50_total = 0 
MSE_svm50_1001 = 0
for i in range(1,1001):
  mse_svm50_total = mse_svm50_total + globals()[f'MSE_svm50_{i}']
AMSE_HbA1c5_svm = mse_svm50_total/1000
print(f'AMSE_HbA1c5_svm = {AMSE_HbA1c5_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c5_svm = 0.03501139680695629
# เวลาที่ใช้ในการประมวลผล 0.0012347698211669922 วินาที
# เวลาที่ใช้ในการประมวลผล 2.057949701944987e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy50_{i}'] = impy.em(globals()[f'HbA1c5{i}'].values.copy())
  globals()[f'MSE_impy50_{i}'] = mean_squared_error(data, globals()[f'imputed_impy50_{i}'])
t_end = time.time()
t50_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy50_total = 0 
MSE_impy50_1001 = 0
for i in range(1,1001):
  mse_impy50_total = mse_impy50_total + globals()[f'MSE_impy50_{i}']
AMSE_HbA1c5_impy = mse_impy50_total/1000
print(f'AMSE_HbA1c5_impy = {AMSE_HbA1c5_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c5_impy = 0.06883597844203031
# เวลาที่ใช้ในการประมวลผล 0.0009675025939941406 วินาที
# เวลาที่ใช้ในการประมวลผล 1.612504323323568e-05 นาที

# %% [markdown]
# # 60 % random nan

# %%
for i in range(1,1001):
  globals()[f'HbA1c6{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*60/100)) 
  index_nan = np.random.choice(globals()[f'HbA1c6{i}']['071_HbA1c'].size, n, replace=False)
  globals()[f'HbA1c6{i}']['071_HbA1c'].ravel()[index_nan] = np.nan

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean60_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean60_{i}'] = mean60_imputer.fit_transform(globals()[f'HbA1c6{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN60_{i}'] = mean_squared_error(data, globals()[f'imputed_mean60_{i}']) # for loop mean_squared_error
t_end = time.time()
t60_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean60_total = 0 
MSE_MEAN60_1001 = 0
for i in range(1,1001):
  mse_mean60_total = mse_mean60_total + globals()[f'MSE_MEAN60_{i}']
AMSE_HbA1c6_mean = mse_mean60_total/1000
print(f'AMSE_HbA1c6_mean = {AMSE_HbA1c6_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c6_mean = 0.04279367239575731
# เวลาที่ใช้ในการประมวลผล 0.0014934539794921875 วินาที
# เวลาที่ใช้ในการประมวลผล 2.4890899658203126e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF60_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf60_{i}'] = MF60_imputer.fit_transform(globals()[f'HbA1c6{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF60_{i}'] = mean_squared_error(data, globals()[f'imputed_mf60_{i}']) # for loop mean_squared_error
t_end = time.time()
t60_MF = (t_end- t_start)

# %%
t_start = time.time()
mse_mf60_total = 0 
MSE_MF60_1001 = 0
for i in range(1,1001):
  mse_mf60_total = mse_mf60_total + globals()[f'MSE_MF60_{i}']
AMSE_HbA1c6_mf = mse_mf60_total/1000
print(f'AMSE_HbA1c6_mf = {AMSE_HbA1c6_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c6_mf = 0.043321567611613786
# เวลาที่ใช้ในการประมวลผล 0.0013720989227294922 วินาที
# เวลาที่ใช้ในการประมวลผล 2.286831537882487e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN60_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN60_{i}'] = KNN60_imputer.fit_transform(globals()[f'HbA1c6{i}'].copy())
  globals()[f'MSE_KNN60_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN60_{i}'])
t_end = time.time()
t60_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn60_total = 0 
MSE_KNN60_1001 = 0
for i in range(1,1001):
  mse_knn60_total = mse_knn60_total + globals()[f'MSE_KNN60_{i}']
AMSE_HbA1c6_knn = mse_knn60_total/1000
print(f'AMSE_HbA1c6_knn = {AMSE_HbA1c6_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c6_knn = 0.04169391402714932
# เวลาที่ใช้ในการประมวลผล 0.002518892288208008 วินาที
# เวลาที่ใช้ในการประมวลผล 4.198153813680013e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp60 = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr60_{i}'] = imp60.fit_transform(globals()[f'HbA1c6{i}'].copy())
  globals()[f'MSE_lr60_{i}'] = mean_squared_error(data, globals()[f'imputed_lr60_{i}'])
t_end = time.time()
t60_LR = (t_end- t_start)

# %%
t_start = time.time()
mse_lr60_total = 0 
MSE_lr60_1001 = 0
for i in range(1,1001):
  mse_lr60_total = mse_lr60_total + globals()[f'MSE_lr60_{i}']
AMSE_HbA1c6_lr = mse_lr60_total/1000
print(f'AMSE_HbA1c6_lr = {AMSE_HbA1c6_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c6_lr = 0.1426470899863053
# เวลาที่ใช้ในการประมวลผล 0.0009732246398925781 วินาที
# เวลาที่ใช้ในการประมวลผล 1.62204106648763e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm60_{i}'] = svm_svr.fit_transform(globals()[f'HbA1c6{i}'].copy())
  globals()[f'MSE_svm60_{i}'] = mean_squared_error(data, globals()[f'imputed_svm60_{i}'])
t_end = time.time()
t60_SVM = (t_end- t_start)

# %%
t_start = time.time()
mse_svm60_total = 0 
MSE_svm60_1001 = 0
for i in range(1,1001):
  mse_svm60_total = mse_svm60_total + globals()[f'MSE_svm60_{i}']
AMSE_HbA1c6_svm = mse_svm60_total/1000
print(f'AMSE_HbA1c6_svm = {AMSE_HbA1c6_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c6_svm = 0.042214090885816305
# เวลาที่ใช้ในการประมวลผล 0.0012545585632324219 วินาที
# เวลาที่ใช้ในการประมวลผล 2.0909309387207032e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy60_{i}'] = impy.em(globals()[f'HbA1c6{i}'].values.copy())
  globals()[f'MSE_impy60_{i}'] = mean_squared_error(data, globals()[f'imputed_impy60_{i}'])
t_end = time.time()
t60_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy60_total = 0 
MSE_impy60_1001 = 0
for i in range(1,1001):
  mse_impy60_total = mse_impy60_total + globals()[f'MSE_impy60_{i}']
AMSE_HbA1c6_impy = mse_impy60_total/1000
print(f'AMSE_HbA1c6_impy = {AMSE_HbA1c6_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_HbA1c6_impy = 0.08432952140806198
# เวลาที่ใช้ในการประมวลผล 0.0012781620025634766 วินาที
# เวลาที่ใช้ในการประมวลผล 2.1302700042724608e-05 นาที

# %% [markdown]
# # AMSE

# %%
amse_value = {'Method':['MEAN','Miss Forest','KNN','MICE-LR','MICE-SVM','EM'],
              '10%':[AMSE_HbA1c1_mean,AMSE_HbA1c1_mf,AMSE_HbA1c1_knn,AMSE_HbA1c1_lr,AMSE_HbA1c1_svm,AMSE_HbA1c1_impy],
      '20%':[AMSE_HbA1c2_mean,AMSE_HbA1c2_mf,AMSE_HbA1c2_knn,AMSE_HbA1c2_lr,AMSE_HbA1c2_svm,AMSE_HbA1c2_impy],
      '30%':[AMSE_HbA1c3_mean,AMSE_HbA1c3_mf,AMSE_HbA1c3_knn,AMSE_HbA1c3_lr,AMSE_HbA1c3_svm,AMSE_HbA1c3_impy],
      '40%':[AMSE_HbA1c4_mean,AMSE_HbA1c4_mf,AMSE_HbA1c4_knn,AMSE_HbA1c4_lr,AMSE_HbA1c4_svm,AMSE_HbA1c4_impy],
      '50%':[AMSE_HbA1c5_mean,AMSE_HbA1c5_mf,AMSE_HbA1c5_knn,AMSE_HbA1c5_lr,AMSE_HbA1c5_svm,AMSE_HbA1c5_impy]
      ,'60%':[AMSE_HbA1c6_mean,AMSE_HbA1c6_mf,AMSE_HbA1c6_knn,AMSE_HbA1c6_lr,AMSE_HbA1c6_svm,AMSE_HbA1c6_impy]}

# %%
data_AMSE = pd.DataFrame.from_dict(amse_value)
data_AMSE
# Out:
#         Method       10%       20%       30%       40%       50%       60%
# 0         MEAN  0.006941  0.014051  0.021101  0.028492  0.035503  0.042794
# 1  Miss Forest  0.006577  0.013472  0.020403  0.028021  0.035461  0.043322
# 2          KNN  0.007122  0.014169  0.020815  0.027876  0.020815  0.041694
# 3      MICE-LR  0.009928  0.021275  0.033861  0.052340  0.077098  0.142647
# 4     MICE-SVM  0.006831  0.013772  0.020708  0.028008  0.035011  0.042214
# 5           EM  0.013336  0.026164  0.040029  0.054576  0.068836  0.084330

# %% [markdown]
# # เวลาทั้งหมดในการรัน

# %% [markdown]
# ## second

# %%
data_t_sec = {'Method':['MEAN','Miss Forest','KNN','MICE-LR','MICE-SVM','EM'],'10%':[t10_MEAN,t10_MF,t10_KNN,t10_LR,t10_SVM,t10_EM],
      '20%':[t20_MEAN,t20_MF,t20_KNN,t20_LR,t20_SVM,t20_EM],'30%':[t30_MEAN,t30_MF,t30_KNN,t30_LR,t30_SVM,t30_EM],'40%':[t40_MEAN,t40_MF,t40_KNN,t40_LR,t40_SVM,t40_EM],
      '50%':[t50_MEAN,t50_MF,t50_KNN,t50_LR,t50_SVM,t50_EM],'60%':[t60_MEAN,t60_MF,t60_KNN,t60_LR,t60_SVM,t60_EM]}

# %%
data_second = pd.DataFrame.from_dict(data_t_sec)
data_second
# Out:
#         Method         10%         20%         30%         40%         50%  \
# 0         MEAN    4.205024    4.235600    4.547260    4.308031    4.405372
# 1  Miss Forest  801.569059  793.408707  791.015599  773.930037  791.230023
# 2          KNN    5.173805    5.549123    5.832476    5.814756   10.324897
# 3      MICE-LR   58.873758   60.345972   60.498466   60.031806   62.212270
# 4     MICE-SVM  125.898914  129.382077  127.035928  128.345929  130.048536
# 5           EM    6.751943   12.472715   17.434133   22.995744   28.711006
#
#           60%
# 0    4.450374
# 1  795.494354
# 2   11.793588
# 3   62.786722
# 4  130.562297
# 5   34.615992

# %% [markdown]
# ## minutes

# %%
data_t_min = {'Method':['MEAN','Miss Forest','KNN','MICE-LR','MICE-SVM','EM'],'10%':[t10_MEAN/60,t10_MF/60,t10_KNN/60,t10_LR/60,t10_SVM/60,t10_EM/60],
      '20%':[t20_MEAN/60,t20_MF/60,t20_KNN/60,t20_LR/60,t20_SVM/60,t20_EM/60],'30%':[t30_MEAN/60,t30_MF/60,t30_KNN/60,t30_LR/60,t30_SVM/60,t30_EM/60]
      ,'40%':[t40_MEAN/60,t40_MF/60,t40_KNN/60,t40_LR/60,t40_SVM/60,t40_EM/60],'50%':[t50_MEAN/60,t50_MF/60,t50_KNN/60,t50_LR/60,t50_SVM/60,t50_EM/60],
      '60%':[t60_MEAN/60,t60_MF/60,t60_KNN/60,t60_LR/60,t60_SVM/60,t60_EM/60]}

# %%
data_minutes = pd.DataFrame.from_dict(data_t_min)
data_minutes
# Out:
#         Method        10%        20%        30%        40%        50%  \
# 0         MEAN   0.070084   0.070593   0.075788   0.071801   0.073423
# 1  Miss Forest  13.359484  13.223478  13.183593  12.898834  13.187167
# 2          KNN   0.086230   0.092485   0.097208   0.096913   0.172082
# 3      MICE-LR   0.981229   1.005766   1.008308   1.000530   1.036871
# 4     MICE-SVM   2.098315   2.156368   2.117265   2.139099   2.167476
# 5           EM   0.112532   0.207879   0.290569   0.383262   0.478517
#
#          60%
# 0   0.074173
# 1  13.258239
# 2   0.196560
# 3   1.046445
# 4   2.176038
# 5   0.576933
