# %% [markdown]
# <a href="https://colab.research.google.com/github/BooEiEi/project/blob/main/004_Uric_Acid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #นำเข้า pandas แทนที่ด้วย pd
import os# os ใช้จัดการกับไฟล์ ว่าอยู่ที่ไหน
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive #นำเข้าข้อมูลจาก drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/project'# ชี้ dirve ที่เราต้องการ
import missingno as mno
import missingno as msno
from sklearn import linear_model
# %matplotlib inline
import matplotlib
import sklearn 
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_squared_error
import time
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv(os.path.join(path, 'DFforCreateNaN.csv'))
data = data.drop(['Unnamed: 0'], axis=1)
data
# Out:
#      Sex  AgeSYear  Weight  Height   BMI  Systolic  Diastolic  HeartRate  \
# 0      2      57.0    47.4   153.0  20.2     114.0       75.0       69.0
# 1      2      24.0    53.2   157.0  21.6     103.0       69.0       78.0
# 2      2      62.0    54.4   165.0  20.0      95.0       75.0       83.0
# 3      2      35.0    56.3   161.0  21.7      95.0       57.0       72.0
# 4      1      46.0    72.3   170.0  25.0     133.0       77.0      107.0
# ..   ...       ...     ...     ...   ...       ...        ...        ...
# 148    1      60.0    72.0   170.0  24.9     131.0       74.0       69.0
# 149    1      58.0    62.0   168.0  22.0     103.0       76.0       72.0
# 150    2      42.0    55.5   165.0  20.4     102.0       52.0       77.0
# 151    2      61.0    61.8   159.0  24.4     117.0       60.0       72.0
# 152    2      31.0    58.2   169.0  20.4     108.0       69.0       73.0
#
#       SMM  Fat Mass  ...  003_Creatinine  004_Uric Acid  005_Cholesterol  \
# 0    19.3      12.5  ...             1.0            5.0            176.0
# 1    21.3      14.6  ...             0.8            5.2            159.0
# 2    21.6      15.2  ...             0.7            4.1            230.0
# 3    22.5      15.4  ...             0.6            5.0            198.0
# 4    29.2      19.0  ...             0.9            6.9            194.0
# ..    ...       ...  ...             ...            ...              ...
# 148  30.5      13.8  ...             0.9            6.9            182.0
# 149  27.8      11.9  ...             1.0            6.8            191.0
# 150  22.9      14.1  ...             0.8            4.7            212.0
# 151  23.4      19.2  ...             0.8            5.1            235.0
# 152  25.0      13.0  ...             0.7            4.3            200.0
#
#      006_Triglyceride  008_HDL-C  009_LDL  010_AST  012_ALT  \
# 0                51.0       72.0     94.0     16.0     16.0
# 1                45.0       52.0     98.0     13.0     17.0
# 2                94.0       61.0    151.0     18.0     31.0
# 3                47.0       68.0    120.0     16.0     20.0
# 4                63.0       60.0    122.0     15.0     19.0
# ..                ...        ...      ...      ...      ...
# 148             179.0       39.0    107.0     36.0     31.0
# 149              62.0       47.0    132.0     16.0     33.0
# 150              68.0       63.0    135.0     11.0     16.0
# 151              66.0       56.0    166.0     15.0     23.0
# 152              44.0       56.0    135.0     14.0     21.0
#
#      013_Alkaline Phos  071_HbA1c
# 0                 62.0        5.1
# 1                 50.0        5.4
# 2                 76.0        5.6
# 3                 35.0        5.1
# 4                 69.0        5.2
# ..                 ...        ...
# 148               79.0        6.5
# 149               42.0        6.8
# 150               33.0        4.8
# 151               44.0        5.4
# 152               31.0        4.7
#
# [153 rows x 26 columns]

# %% [markdown]
# # 10 % random nan

# %%
for i in range(1,1001):
  globals()[f'Uric_Acid1{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*10/100)) 
  index_nan = np.random.choice(globals()[f'Uric_Acid1{i}']['004_Uric Acid'].size, n, replace=False)
  globals()[f'Uric_Acid1{i}']['004_Uric Acid'].ravel()[index_nan] = np.nan

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean10_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean10_{i}'] = mean10_imputer.fit_transform(globals()[f'Uric_Acid1{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN10_{i}'] = mean_squared_error(data, globals()[f'imputed_mean10_{i}']) # for loop mean_squared_error
t_end = time.time()
t10_MEAN= (t_end- t_start)

# %%
t_start = time.time()
mse_mean10_total = 0 
MSE_MEAN10_1001 = 0
for i in range(1,1001):
  mse_mean10_total = mse_mean10_total + globals()[f'MSE_MEAN10_{i}']
AMSE_Uric_Acid1_mean = mse_mean10_total/1000
print(f'AMSE_Uric_Acid1_mean = {AMSE_Uric_Acid1_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid1_mean = 0.005142452003663508
# เวลาที่ใช้ในการประมวลผล 0.0007467269897460938 วินาที
# เวลาที่ใช้ในการประมวลผล 1.2445449829101563e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting missingpy
#   Downloading missingpy-0.2.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 6.2 MB/s
# Installing collected packages: missingpy
# Successfully installed missingpy-0.2.0

# %%
t_start = time.time()
MF10_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf10_{i}'] = MF10_imputer.fit_transform(globals()[f'Uric_Acid1{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF10_{i}'] = mean_squared_error(data, globals()[f'imputed_mf10_{i}']) # for loop mean_squared_error
t_end = time.time()
t10_MF= (t_end- t_start)

# %%
t_start = time.time()
mse_mf10_total = 0 
MSE_MF10_1001 = 0
for i in range(1,1001):
  mse_mf10_total = mse_mf10_total + globals()[f'MSE_MF10_{i}']
AMSE_Uric_Acid1_mf = mse_mf10_total/1000
print(f'AMSE_Uric_Acid1_mf = {AMSE_Uric_Acid1_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid1_mf = 0.0026914295316742103
# เวลาที่ใช้ในการประมวลผล 0.0012166500091552734 วินาที
# เวลาที่ใช้ในการประมวลผล 2.027750015258789e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN10_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN10_{i}'] = KNN10_imputer.fit_transform(globals()[f'Uric_Acid1{i}'].copy())
  globals()[f'MSE_KNN10_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN10_{i}'])
t_end = time.time()
t10_KNN= (t_end- t_start)

# %%
t_start = time.time()
mse_knn10_total = 0 
MSE_KNN10_1001 = 0
for i in range(1,1001):
  mse_knn10_total = mse_knn10_total + globals()[f'MSE_KNN10_{i}']
AMSE_Uric_Acid1_knn = mse_knn10_total/1000
print(f'AMSE_Uric_Acid1_knn = {AMSE_Uric_Acid1_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid1_knn = 0.0035607945701357398
# เวลาที่ใช้ในการประมวลผล 0.0009844303131103516 วินาที
# เวลาที่ใช้ในการประมวลผล 1.6407171885172525e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr10_{i}'] = imp.fit_transform(globals()[f'Uric_Acid1{i}'].copy())
  globals()[f'MSE_lr10_{i}'] = mean_squared_error(data, globals()[f'imputed_lr10_{i}'])
t_end = time.time()
t10_LR= (t_end- t_start)

# %%
t_start = time.time()
mse_lr10_total = 0 
MSE_lr10_1001 = 0
for i in range(1,1001):
  mse_lr10_total = mse_lr10_total + globals()[f'MSE_lr10_{i}']
AMSE_Uric_Acid1_lr = mse_lr10_total/1000
print(f'AMSE_Uric_Acid1_lr = {AMSE_Uric_Acid1_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid1_lr = 0.00316561795299414
# เวลาที่ใช้ในการประมวลผล 0.001444101333618164 วินาที
# เวลาที่ใช้ในการประมวลผล 2.4068355560302735e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm10_{i}'] = svm_svr.fit_transform(globals()[f'Uric_Acid1{i}'].copy())
  globals()[f'MSE_svm10_{i}'] = mean_squared_error(data, globals()[f'imputed_svm10_{i}'])
t_end = time.time()
t10_SVM= (t_end- t_start)

# %%
t_start = time.time()
mse_svm10_total = 0 
MSE_svm10_1001 = 0
for i in range(1,1001):
  mse_svm10_total = mse_svm10_total + globals()[f'MSE_svm10_{i}']
AMSE_Uric_Acid1_svm = mse_svm10_total/1000
print(f'AMSE_Uric_Acid1_svm = {AMSE_Uric_Acid1_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid1_svm = 0.0033968258477037037
# เวลาที่ใช้ในการประมวลผล 0.0008521080017089844 วินาที
# เวลาที่ใช้ในการประมวลผล 1.4201800028483074e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting impyute
#   Downloading impyute-0.0.8-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)
# Installing collected packages: impyute
# Successfully installed impyute-0.0.8

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy10_{i}'] = impy.em(globals()[f'Uric_Acid1{i}'].values.copy())
  globals()[f'MSE_impy10_{i}'] = mean_squared_error(data, globals()[f'imputed_impy10_{i}'])
t_end = time.time()
t10_EM= (t_end- t_start)

# %%
t_start = time.time()
mse_impy10_total = 0 
MSE_impy10_1001 = 0
for i in range(1,1001):
  mse_impy10_total = mse_impy10_total + globals()[f'MSE_impy10_{i}']
AMSE_Uric_Acid1_impy = mse_impy10_total/1000
print(f'AMSE_Uric_Acid1_impy = {AMSE_Uric_Acid1_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid1_impy = 0.009785569799044217
# เวลาที่ใช้ในการประมวลผล 0.0008749961853027344 วินาที
# เวลาที่ใช้ในการประมวลผล 1.4583269755045572e-05 นาที

# %% [markdown]
# # 20 % random nan

# %%
for i in range(1,1001):
  globals()[f'Uric_Acid2{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*10/100)) 
  index_nan = np.random.choice(globals()[f'Uric_Acid2{i}']['004_Uric Acid'].size, n, replace=False)
  globals()[f'Uric_Acid2{i}']['004_Uric Acid'].ravel()[index_nan] = np.nan

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean20_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean20_{i}'] = mean10_imputer.fit_transform(globals()[f'Uric_Acid2{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN20_{i}'] = mean_squared_error(data, globals()[f'imputed_mean20_{i}']) # for loop mean_squared_error
t_end = time.time()
t20_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean20_total = 0 
MSE_MEAN20_1001 = 0
for i in range(1,1001):
  mse_mean20_total = mse_mean20_total + globals()[f'MSE_MEAN20_{i}']
AMSE_Uric_Acid2_mean = mse_mean20_total/1000
print(f'AMSE_Uric_Acid2_mean = {AMSE_Uric_Acid2_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid2_mean = 0.005142452003663508
# เวลาที่ใช้ในการประมวลผล 0.0012426376342773438 วินาที
# เวลาที่ใช้ในการประมวลผล 2.0710627237955728e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF20_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf20_{i}'] = MF20_imputer.fit_transform(globals()[f'Uric_Acid2{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF20_{i}'] = mean_squared_error(data, globals()[f'imputed_mf20_{i}']) # for loop mean_squared_error
t_end = time.time()
t20_MF = (t_end- t_start)

# %%
t_start = time.time()
mse_mf20_total = 0 
MSE_MF20_1001 = 0
for i in range(1,1001):
  mse_mf20_total = mse_mf20_total + globals()[f'MSE_MF20_{i}']
AMSE_Uric_Acid2_mf = mse_mf20_total/1000
print(f'AMSE_Uric_Acid2_mf = {AMSE_Uric_Acid2_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid2_mf = 0.00269142953167421
# เวลาที่ใช้ในการประมวลผล 0.0013475418090820312 วินาที
# เวลาที่ใช้ในการประมวลผล 2.2459030151367188e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN20_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN20_{i}'] = KNN10_imputer.fit_transform(globals()[f'Uric_Acid2{i}'].copy())
  globals()[f'MSE_KNN20_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN20_{i}'])
t_end = time.time()
t20_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn20_total = 0 
MSE_KNN20_1001 = 0
for i in range(1,1001):
  mse_knn20_total = mse_knn20_total + globals()[f'MSE_KNN20_{i}']
AMSE_Uric_Acid2_knn = mse_knn20_total/1000
print(f'AMSE_Uric_Acid2_knn = {AMSE_Uric_Acid2_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid2_knn = 0.0035607945701357398
# เวลาที่ใช้ในการประมวลผล 0.0008311271667480469 วินาที
# เวลาที่ใช้ในการประมวลผล 1.3852119445800782e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp20 = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr20_{i}'] = imp20.fit_transform(globals()[f'Uric_Acid2{i}'].copy())
  globals()[f'MSE_lr20_{i}'] = mean_squared_error(data, globals()[f'imputed_lr20_{i}'])
t_end = time.time()
t20_LR = (t_end- t_start)

# %%
t_start = time.time()
mse_lr20_total = 0 
MSE_lr20_1001 = 0
for i in range(1,1001):
  mse_lr20_total = mse_lr20_total + globals()[f'MSE_lr20_{i}']
AMSE_Uric_Acid2_lr = mse_lr20_total/1000
print(f'AMSE_Uric_Acid2_lr = {AMSE_Uric_Acid2_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid2_lr = 0.00316561795299414
# เวลาที่ใช้ในการประมวลผล 0.0009126663208007812 วินาที
# เวลาที่ใช้ในการประมวลผล 1.5211105346679687e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm20_{i}'] = svm_svr.fit_transform(globals()[f'Uric_Acid2{i}'].copy())
  globals()[f'MSE_svm20_{i}'] = mean_squared_error(data, globals()[f'imputed_svm20_{i}'])
t_end = time.time()
t20_SVM = (t_end- t_start)

# %%
t_start = time.time()
mse_svm20_total = 0 
MSE_svm20_1001 = 0
for i in range(1,1001):
  mse_svm20_total = mse_svm20_total + globals()[f'MSE_svm20_{i}']
AMSE_Uric_Acid2_svm = mse_svm20_total/1000
print(f'AMSE_Uric_Acid2_svm = {AMSE_Uric_Acid2_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid2_svm = 0.0033968258477037037
# เวลาที่ใช้ในการประมวลผล 0.0009417533874511719 วินาที
# เวลาที่ใช้ในการประมวลผล 1.5695889790852863e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy20_{i}'] = impy.em(globals()[f'Uric_Acid2{i}'].values.copy())
  globals()[f'MSE_impy20_{i}'] = mean_squared_error(data, globals()[f'imputed_impy20_{i}'])
t_end = time.time()
t20_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy20_total = 0 
MSE_impy20_1001 = 0
for i in range(1,1001):
  mse_impy20_total = mse_impy20_total + globals()[f'MSE_impy20_{i}']
AMSE_Uric_Acid2_impy = mse_impy20_total/1000
print(f'AMSE_Uric_Acid2_impy = {AMSE_Uric_Acid2_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid2_impy = 0.009785569799044217
# เวลาที่ใช้ในการประมวลผล 0.0008654594421386719 วินาที
# เวลาที่ใช้ในการประมวลผล 1.4424324035644531e-05 นาที

# %% [markdown]
# # 30 % random nan

# %%
for i in range(1,1001):
  globals()[f'Uric_Acid3{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*10/100)) 
  index_nan = np.random.choice(globals()[f'Uric_Acid3{i}']['004_Uric Acid'].size, n, replace=False)
  globals()[f'Uric_Acid3{i}']['004_Uric Acid'].ravel()[index_nan] = np.nan

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean30_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean30_{i}'] = mean30_imputer.fit_transform(globals()[f'Uric_Acid3{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN30_{i}'] = mean_squared_error(data, globals()[f'imputed_mean30_{i}']) # for loop mean_squared_error
t_end = time.time()
t30_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean30_total = 0 
MSE_MEAN30_1001 = 0
for i in range(1,1001):
  mse_mean30_total = mse_mean30_total + globals()[f'MSE_MEAN30_{i}']
AMSE_Uric_Acid3_mean = mse_mean30_total/1000
print(f'AMSE_Uric_Acid3_mean = {AMSE_Uric_Acid3_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid3_mean = 0.005142452003663508
# เวลาที่ใช้ในการประมวลผล 0.0010251998901367188 วินาที
# เวลาที่ใช้ในการประมวลผล 1.708666483561198e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF30_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf30_{i}'] = MF30_imputer.fit_transform(globals()[f'Uric_Acid3{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF30_{i}'] = mean_squared_error(data, globals()[f'imputed_mf30_{i}']) # for loop mean_squared_error
t_end = time.time()
t30_MF = (t_end- t_start)

# %%
t_start = time.time()
mse_mf30_total = 0 
MSE_MF30_1001 = 0
for i in range(1,1001):
  mse_mf30_total = mse_mf30_total + globals()[f'MSE_MF30_{i}']
AMSE_Uric_Acid3_mf = mse_mf30_total/1000
print(f'AMSE_Uric_Acid3_mf = {AMSE_Uric_Acid3_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid3_mf = 0.0026914295316742103
# เวลาที่ใช้ในการประมวลผล 0.0011126995086669922 วินาที
# เวลาที่ใช้ในการประมวลผล 1.8544991811116536e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN30_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN30_{i}'] = KNN30_imputer.fit_transform(globals()[f'Uric_Acid3{i}'].copy())
  globals()[f'MSE_KNN30_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN30_{i}'])
t_end = time.time()
t30_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn30_total = 0 
MSE_KNN30_1001 = 0
for i in range(1,1001):
  mse_knn30_total = mse_knn30_total + globals()[f'MSE_KNN30_{i}']
AMSE_Uric_Acid3_knn = mse_knn30_total/1000
print(f'AMSE_Uric_Acid3_knn = {AMSE_Uric_Acid3_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid3_knn = 0.0035607945701357398
# เวลาที่ใช้ในการประมวลผล 0.001157522201538086 วินาที
# เวลาที่ใช้ในการประมวลผล 1.9292036692301433e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp30 = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr30_{i}'] = imp30.fit_transform(globals()[f'Uric_Acid3{i}'].copy())
  globals()[f'MSE_lr30_{i}'] = mean_squared_error(data, globals()[f'imputed_lr30_{i}'])
t_end = time.time()
t30_LR = (t_end- t_start)

# %%
t_start = time.time()
mse_lr30_total = 0 
MSE_lr30_1001 = 0
for i in range(1,1001):
  mse_lr30_total = mse_lr30_total + globals()[f'MSE_lr30_{i}']
AMSE_Uric_Acid3_lr = mse_lr30_total/1000
print(f'AMSE_Uric_Acid3_lr = {AMSE_Uric_Acid3_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid3_lr = 0.00316561795299414
# เวลาที่ใช้ในการประมวลผล 0.0011870861053466797 วินาที
# เวลาที่ใช้ในการประมวลผล 1.978476842244466e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm30_{i}'] = svm_svr.fit_transform(globals()[f'Uric_Acid3{i}'].copy())
  globals()[f'MSE_svm30_{i}'] = mean_squared_error(data, globals()[f'imputed_svm30_{i}'])
t_end = time.time()
t30_SVM = (t_end- t_start)

# %%
t_start = time.time()
mse_svm30_total = 0 
MSE_svm30_1001 = 0
for i in range(1,1001):
  mse_svm30_total = mse_svm30_total + globals()[f'MSE_svm30_{i}']
AMSE_Uric_Acid3_svm = mse_svm30_total/1000
print(f'AMSE_Uric_Acid3_svm = {AMSE_Uric_Acid3_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid3_svm = 0.0033968258477037037
# เวลาที่ใช้ในการประมวลผล 0.0009889602661132812 วินาที
# เวลาที่ใช้ในการประมวลผล 1.6482671101888022e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy30_{i}'] = impy.em(globals()[f'Uric_Acid3{i}'].values.copy())
  globals()[f'MSE_impy30_{i}'] = mean_squared_error(data, globals()[f'imputed_impy30_{i}'])
t_end = time.time()
t30_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy30_total = 0 
MSE_impy30_1001 = 0
for i in range(1,1001):
  mse_impy30_total = mse_impy30_total + globals()[f'MSE_impy30_{i}']
AMSE_Uric_Acid3_impy = mse_impy30_total/1000
print(f'AMSE_Uric_Acid3_impy = {AMSE_Uric_Acid3_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid3_impy = 0.009785569799044217
# เวลาที่ใช้ในการประมวลผล 0.0009002685546875 วินาที
# เวลาที่ใช้ในการประมวลผล 1.5004475911458333e-05 นาที

# %% [markdown]
# # 40 % random nan

# %%
for i in range(1,1001):
  globals()[f'Uric_Acid4{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*10/100)) 
  index_nan = np.random.choice(globals()[f'Uric_Acid4{i}']['004_Uric Acid'].size, n, replace=False)
  globals()[f'Uric_Acid4{i}']['004_Uric Acid'].ravel()[index_nan] = np.nan

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean40_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean40_{i}'] = mean40_imputer.fit_transform(globals()[f'Uric_Acid4{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN40_{i}'] = mean_squared_error(data, globals()[f'imputed_mean40_{i}']) # for loop mean_squared_error
t_end = time.time()
t40_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean40_total = 0 
MSE_MEAN40_1001 = 0
for i in range(1,1001):
  mse_mean40_total = mse_mean40_total + globals()[f'MSE_MEAN40_{i}']
AMSE_Uric_Acid4_mean = mse_mean40_total/1000
print(f'AMSE_Uric_Acid4_mean = {AMSE_Uric_Acid4_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid4_mean = 0.005142452003663508
# เวลาที่ใช้ในการประมวลผล 0.0009729862213134766 วินาที
# เวลาที่ใช้ในการประมวลผล 1.6216437021891276e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF40_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf40_{i}'] = MF40_imputer.fit_transform(globals()[f'Uric_Acid4{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF40_{i}'] = mean_squared_error(data, globals()[f'imputed_mf40_{i}']) # for loop mean_squared_error
t_end = time.time()
t40_MF = (t_end- t_start)

# %%
t_start = time.time()
mse_mf40_total = 0 
MSE_MF40_1001 = 0
for i in range(1,1001):
  mse_mf40_total = mse_mf40_total + globals()[f'MSE_MF40_{i}']
AMSE_Uric_Acid4_mf = mse_mf40_total/1000
print(f'AMSE_Uric_Acid4_mf = {AMSE_Uric_Acid4_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid4_mf = 0.0026914295316742103
# เวลาที่ใช้ในการประมวลผล 0.0013489723205566406 วินาที
# เวลาที่ใช้ในการประมวลผล 2.2482872009277343e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN40_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN40_{i}'] = KNN40_imputer.fit_transform(globals()[f'Uric_Acid4{i}'].copy())
  globals()[f'MSE_KNN40_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN40_{i}'])
t_end = time.time()
t40_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn40_total = 0 
MSE_KNN40_1001 = 0
for i in range(1,1001):
  mse_knn40_total = mse_knn40_total + globals()[f'MSE_KNN40_{i}']
AMSE_Uric_Acid4_knn = mse_knn40_total/1000
print(f'AMSE_Uric_Acid4_knn = {AMSE_Uric_Acid4_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid4_knn = 0.0035607945701357398
# เวลาที่ใช้ในการประมวลผล 0.0009315013885498047 วินาที
# เวลาที่ใช้ในการประมวลผล 1.5525023142496743e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp40 = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr40_{i}'] = imp40.fit_transform(globals()[f'Uric_Acid4{i}'].copy())
  globals()[f'MSE_lr40_{i}'] = mean_squared_error(data, globals()[f'imputed_lr40_{i}'])
t_end = time.time()
t40_LR = (t_end- t_start)

# %%
t_start = time.time()
mse_lr40_total = 0 
MSE_lr40_1001 = 0
for i in range(1,1001):
  mse_lr40_total = mse_lr40_total + globals()[f'MSE_lr40_{i}']
AMSE_Uric_Acid4_lr = mse_lr40_total/1000
print(f'AMSE_Uric_Acid4_lr = {AMSE_Uric_Acid4_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid4_lr = 0.00316561795299414
# เวลาที่ใช้ในการประมวลผล 0.0009849071502685547 วินาที
# เวลาที่ใช้ในการประมวลผล 1.6415119171142577e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm40_{i}'] = svm_svr.fit_transform(globals()[f'Uric_Acid4{i}'].copy())
  globals()[f'MSE_svm40_{i}'] = mean_squared_error(data, globals()[f'imputed_svm40_{i}'])
t_end = time.time()
t40_SVM = (t_end- t_start)

# %%
t_start = time.time()
mse_svm40_total = 0 
MSE_svm40_1001 = 0
for i in range(1,1001):
  mse_svm40_total = mse_svm40_total + globals()[f'MSE_svm40_{i}']
AMSE_Uric_Acid4_svm = mse_svm40_total/1000
print(f'AMSE_Uric_Acid4_svm = {AMSE_Uric_Acid4_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid4_svm = 0.0033968258477037037
# เวลาที่ใช้ในการประมวลผล 0.0010917186737060547 วินาที
# เวลาที่ใช้ในการประมวลผล 1.8195311228434244e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy40_{i}'] = impy.em(globals()[f'Uric_Acid4{i}'].values.copy())
  globals()[f'MSE_impy40_{i}'] = mean_squared_error(data, globals()[f'imputed_impy40_{i}'])
t_end = time.time()
t40_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy40_total = 0 
MSE_impy40_1001 = 0
for i in range(1,1001):
  mse_impy40_total = mse_impy40_total + globals()[f'MSE_impy40_{i}']
AMSE_Uric_Acid4_impy = mse_impy40_total/1000
print(f'AMSE_Uric_Acid4_impy = {AMSE_Uric_Acid4_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid4_impy = 0.009785569799044217
# เวลาที่ใช้ในการประมวลผล 0.0012960433959960938 วินาที
# เวลาที่ใช้ในการประมวลผล 2.160072326660156e-05 นาที

# %% [markdown]
# # 50 % random nan

# %%
for i in range(1,1001):
  globals()[f'Uric_Acid5{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*10/100)) 
  index_nan = np.random.choice(globals()[f'Uric_Acid5{i}']['004_Uric Acid'].size, n, replace=False)
  globals()[f'Uric_Acid5{i}']['004_Uric Acid'].ravel()[index_nan] = np.nan

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean50_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean50_{i}'] = mean50_imputer.fit_transform(globals()[f'Uric_Acid5{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN50_{i}'] = mean_squared_error(data, globals()[f'imputed_mean50_{i}']) # for loop mean_squared_error
t_end = time.time()
t50_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean50_total = 0 
MSE_MEAN50_1001 = 0
for i in range(1,1001):
  mse_mean50_total = mse_mean50_total + globals()[f'MSE_MEAN50_{i}']
AMSE_Uric_Acid5_mean = mse_mean50_total/1000
print(f'AMSE_Uric_Acid5_mean = {AMSE_Uric_Acid5_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid5_mean = 0.005142452003663508
# เวลาที่ใช้ในการประมวลผล 0.001314401626586914 วินาที
# เวลาที่ใช้ในการประมวลผล 2.190669377644857e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF50_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf50_{i}'] = MF50_imputer.fit_transform(globals()[f'Uric_Acid5{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF50_{i}'] = mean_squared_error(data, globals()[f'imputed_mf50_{i}']) # for loop mean_squared_error
t_end = time.time()
t50_MF = (t_end- t_start)

# %%
t_start = time.time()
mse_mf50_total = 0 
MSE_MF50_1001 = 0
for i in range(0,1001):
  mse_mf50_total = mse_mf50_total + globals()[f'MSE_MF50_{i+1}']
AMSE_Uric_Acid5_mf = mse_mf50_total/1000
print(f'AMSE_Uric_Acid5_mf = {AMSE_Uric_Acid5_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid5_mf = 0.0026914295316742103
# เวลาที่ใช้ในการประมวลผล 0.001186370849609375 วินาที
# เวลาที่ใช้ในการประมวลผล 1.9772847493489584e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN50_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN50_{i}'] = KNN30_imputer.fit_transform(globals()[f'Uric_Acid5{i}'].copy())
  globals()[f'MSE_KNN50_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN50_{i}'])
t_end = time.time()
t50_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn50_total = 0 
MSE_KNN50_1001 = 0
for i in range(1,1001):
  mse_knn50_total = mse_knn30_total + globals()[f'MSE_KNN50_{i}']
AMSE_Uric_Acid5_knn = mse_knn30_total/1000
print(f'AMSE_Uric_Acid5_knn = {AMSE_Uric_Acid5_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid5_knn = 0.0035607945701357398
# เวลาที่ใช้ในการประมวลผล 0.0009500980377197266 วินาที
# เวลาที่ใช้ในการประมวลผล 1.5834967295328777e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp50 = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr50_{i}'] = imp50.fit_transform(globals()[f'Uric_Acid5{i}'].copy())
  globals()[f'MSE_lr50_{i}'] = mean_squared_error(data, globals()[f'imputed_lr50_{i}'])
t_end = time.time()
t50_LR = (t_end- t_start)

# %%
t_start = time.time()
mse_lr50_total = 0 
MSE_lr50_1001 = 0
for i in range(1,1001):
  mse_lr50_total = mse_lr50_total + globals()[f'MSE_lr50_{i}']
AMSE_Uric_Acid5_lr = mse_lr50_total/1000
print(f'AMSE_Uric_Acid5_lr = {AMSE_Uric_Acid5_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid5_lr = 0.00316561795299414
# เวลาที่ใช้ในการประมวลผล 0.0009732246398925781 วินาที
# เวลาที่ใช้ในการประมวลผล 1.62204106648763e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm50_{i}'] = svm_svr.fit_transform(globals()[f'Uric_Acid5{i}'].copy())
  globals()[f'MSE_svm50_{i}'] = mean_squared_error(data, globals()[f'imputed_svm50_{i}'])
t_end = time.time()
t50_SVM = (t_end- t_start)

# %%
t_start = time.time()
mse_svm50_total = 0 
MSE_svm50_1001 = 0
for i in range(1,1001):
  mse_svm50_total = mse_svm50_total + globals()[f'MSE_svm50_{i}']
AMSE_Uric_Acid5_svm = mse_svm50_total/1000
print(f'AMSE_Uric_Acid5_svm = {AMSE_Uric_Acid5_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid5_svm = 0.0033968258477037037
# เวลาที่ใช้ในการประมวลผล 0.001081705093383789 วินาที
# เวลาที่ใช้ในการประมวลผล 1.802841822306315e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy50_{i}'] = impy.em(globals()[f'Uric_Acid5{i}'].values.copy())
  globals()[f'MSE_impy50_{i}'] = mean_squared_error(data, globals()[f'imputed_impy50_{i}'])
t_end = time.time()
t50_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy50_total = 0 
MSE_impy50_1001 = 0
for i in range(1,1001):
  mse_impy50_total = mse_impy50_total + globals()[f'MSE_impy50_{i}']
AMSE_Uric_Acid5_impy = mse_impy50_total/1000
print(f'AMSE_Uric_Acid5_impy = {AMSE_Uric_Acid5_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid5_impy = 0.009785569799044217
# เวลาที่ใช้ในการประมวลผล 0.0010654926300048828 วินาที
# เวลาที่ใช้ในการประมวลผล 1.775821050008138e-05 นาที

# %% [markdown]
# # 60 % random nan

# %%
for i in range(1,1001):
  globals()[f'Uric_Acid6{i}'] = data.copy() # for loop variable name
  np.random.seed(i) # for loop seed
  n = int((153*10/100)) 
  index_nan = np.random.choice(globals()[f'Uric_Acid6{i}']['004_Uric Acid'].size, n, replace=False)
  globals()[f'Uric_Acid6{i}']['004_Uric Acid'].ravel()[index_nan] = np.nan

# %% [markdown]
# ## Imputation using Mean

# %%
from sklearn.impute import SimpleImputer

# %%
t_start = time.time()
mean60_imputer = SimpleImputer(strategy='mean')
for i in range(1,1001):
  globals()[f'imputed_mean60_{i}'] = mean60_imputer.fit_transform(globals()[f'Uric_Acid6{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MEAN60_{i}'] = mean_squared_error(data, globals()[f'imputed_mean60_{i}']) # for loop mean_squared_error
t_end = time.time()
t60_MEAN = (t_end- t_start)

# %%
t_start = time.time()
mse_mean60_total = 0 
MSE_MEAN60_1001 = 0
for i in range(1,1001):
  mse_mean60_total = mse_mean60_total + globals()[f'MSE_MEAN60_{i}']
AMSE_Uric_Acid6_mean = mse_mean60_total/1000
print(f'AMSE_Uric_Acid6_mean = {AMSE_Uric_Acid6_mean}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid6_mean = 0.005142452003663508
# เวลาที่ใช้ในการประมวลผล 0.0009589195251464844 วินาที
# เวลาที่ใช้ในการประมวลผล 1.598199208577474e-05 นาที

# %% [markdown]
# ## Imputation using the miss forest

# %%
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base
# !pip install missingpy
import missingpy
from missingpy import MissForest
from sklearn.metrics import mean_squared_error
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingpy in /usr/local/lib/python3.8/dist-packages (0.2.0)

# %%
t_start = time.time()
MF60_imputer = MissForest()
for i in range(1,1001):
  globals()[f'imputed_mf60_{i}'] = MF60_imputer.fit_transform(globals()[f'Uric_Acid6{i}'].copy()) #for loop miss forest impputation 
  globals()[f'MSE_MF60_{i}'] = mean_squared_error(data, globals()[f'imputed_mf60_{i}']) # for loop mean_squared_error
t_end = time.time()
t60_MF = (t_end- t_start)

# %%
t_start = time.time()
mse_mf60_total = 0 
MSE_MF60_1001 = 0
for i in range(1,1001):
  mse_mf60_total = mse_mf60_total + globals()[f'MSE_MF60_{i}']
AMSE_Uric_Acid6_mf = mse_mf60_total/1000
print(f'AMSE_Uric_Acid6_mf = {AMSE_Uric_Acid6_mf}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid6_mf = 0.0026914295316742103
# เวลาที่ใช้ในการประมวลผล 0.0012996196746826172 วินาที
# เวลาที่ใช้ในการประมวลผล 2.1660327911376952e-05 นาที

# %% [markdown]
# ## Imputation using the KNN

# %%
from sklearn import neighbors
from sklearn.impute import KNNImputer

# %%
t_start = time.time()
KNN60_imputer = KNNImputer(n_neighbors = 15)
for i in range(1,1001):
  globals()[f'imputed_KNN60_{i}'] = KNN60_imputer.fit_transform(globals()[f'Uric_Acid6{i}'].copy())
  globals()[f'MSE_KNN60_{i}'] = mean_squared_error(data, globals()[f'imputed_KNN60_{i}'])
t_end = time.time()
t60_KNN = (t_end- t_start)

# %%
t_start = time.time()
mse_knn60_total = 0 
MSE_KNN60_1001 = 0
for i in range(1,1001):
  mse_knn60_total = mse_knn60_total + globals()[f'MSE_KNN60_{i}']
AMSE_Uric_Acid6_knn = mse_knn60_total/1000
print(f'AMSE_Uric_Acid6_knn = {AMSE_Uric_Acid6_knn}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid6_knn = 0.0035607945701357398
# เวลาที่ใช้ในการประมวลผล 0.0009906291961669922 วินาที
# เวลาที่ใช้ในการประมวลผล 1.6510486602783203e-05 นาที

# %% [markdown]
# ## Imputation using the MICE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %% [markdown]
# ### LinearRegression model

# %%
t_start = time.time()
lr = LinearRegression()
for i in range(1,1001):
  imp60 = IterativeImputer(estimator= lr , max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_lr60_{i}'] = imp60.fit_transform(globals()[f'Uric_Acid6{i}'].copy())
  globals()[f'MSE_lr60_{i}'] = mean_squared_error(data, globals()[f'imputed_lr60_{i}'])
t_end = time.time()
t60_LR = (t_end- t_start)
# Out:
# Streaming output truncated to the last 5000 lines.
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.2515057154187978, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 1.3614459751644237, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.6798884591877634, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 2.660125153134376, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 0.9413686246288631, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.2566389557209394, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.5697874984130777, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.1704776010188045, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.112053778832827, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.7198567680313497, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 1.8352368925349891, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.4737520642794983, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.136734651502496, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.6610332125360978, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.395966431490585, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.8242361475772313, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 3.3695566449486973, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.234835664501075, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.6353035462570196, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.4575639086262626, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 1.5191709859170528, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.139232542671439, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.4785261229787308, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.3503752439510945, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.085060350555173, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.8932348640173275, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.4598368281973872, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 1.9824875344148527, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.9662439012805475, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.185788300251958, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.170408923081025, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.745531363172053, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.689091851521021, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.6655816637130734, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 2.0482275632854527, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.07
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.010829118354769, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.8427154809873416, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.649522203953741, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.432701651433919, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.0464929528901328, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.540725474475371, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.07
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.669969227835538, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.6437885272525232, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.6891786801471724, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.9021148191345443, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.3189899385428028, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.3810350672250644, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 2.7047203063005014, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.5384596111753783, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.924579763245772, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.6955178164786453, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.672195460821378, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.5817257338508695, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.9365006683687493, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.068152851625414, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.837268930791061, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.3860649168480323, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.9894217179298828, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.9692885599944274, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.862449652418853, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.4326718932406397, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.3591297405801281, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.588417956449365, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.7209862452037328, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.777837036313703, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.8028719318167328, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.7120801256293898, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.7174704288753588, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.07
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.4807432880582514, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.8199358326036448, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.5317836645628207, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.138830537781941, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.6992883040284026, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.0401633942916995, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.946279803881974, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.791781432437487, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.283882723788526, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.0444244806233005, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.2584468469016175, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.8996221823155706, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.777198707809088, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.6773090755125066, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.9200076464114098, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.4715125648056109, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 2.3382426053471335, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.07
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.6028907078399355, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.3850915496951206, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.132554982553274, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.765818684784466, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.118302384750228, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.6242964534020468, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 1.6693631028046871, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.9281663414916066, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.1210350994503333, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.9557028175617797, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.5293951034078708, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.2259960178607545, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.430688848325076, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 2.716929143044979, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.799993934716177, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.954177589452562, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.8649081093662616, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.4938308098346953, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.0133288873753497, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.043038454691507, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 2.3899312070483916, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.6790009660828122, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.213535881859288, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 2.678911615837583, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.9884679546665307, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.299080519575022, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.4878045005730502, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.1441936339537797, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.7038040023887584, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.6168959880006755, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 2.677402892500189, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.5260070467113342, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.633126515874973, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.6345001051453414, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.776828552667979, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.1138019326649875, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.5712948505138602, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.3242537360341622, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.7426059305574828, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.628778587225134, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 2.2366791674146818, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.8925261170482885, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.7616845078365593, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# ...
# [IterativeImputer] Change: 2.2173187864799715, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.5878250987180396, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.2251554697895282, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 2.324598219835617, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 2.210474342854667, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.6173968455668595, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.2955564070785996, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.21447700336153, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.202556721962033, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.453482485317638, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 1.2317520330816656, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.6088551594468177, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.9816849508237135, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.9102234983187598, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.7940373641283491, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.5110072328477315, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.9113074914813808, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 1.9978792732291222, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.8537185477041334, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.54101524899602, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.4667636204224532, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.627092872318811, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.13421695500078, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.6035927222237856, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 2.591939667411352, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.1876123230829538, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.4461289792361605, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.2637414752824156, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.9323437124317397, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.9934365727437129, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.8925474989660813, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 2.8481610161195965, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.1907657527015258, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.8531478327489959, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.2261823480976233, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.04
# [IterativeImputer] Change: 2.7380244627859387, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.6280930685972725, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.324240834323943, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.896254028970647, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 2.6524684584371014, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.4103911664570496, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 1.3857631389266087, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.06
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.02
# [IterativeImputer] Change: 1.7010728234251369, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.05
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.

# %%
t_start = time.time()
mse_lr60_total = 0 
MSE_lr60_1001 = 0
for i in range(1,1001):
  mse_lr60_total = mse_lr60_total + globals()[f'MSE_lr60_{i}']
AMSE_Uric_Acid6_lr = mse_lr60_total/1000
print(f'AMSE_Uric_Acid6_lr = {AMSE_Uric_Acid6_lr}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid6_lr = 0.00316561795299414
# เวลาที่ใช้ในการประมวลผล 0.0011475086212158203 วินาที
# เวลาที่ใช้ในการประมวลผล 1.912514368693034e-05 นาที

# %% [markdown]
# ### Support Vector Machine model

# %%
t_start = time.time()
regr = svm.SVR()
for i in range(1,1001):
  svm_svr = IterativeImputer(estimator= regr, max_iter= 10, verbose=2, imputation_order='roman',initial_strategy = 'mean',random_state= i)
  globals()[f'imputed_svm60_{i}'] = svm_svr.fit_transform(globals()[f'Uric_Acid6{i}'].copy())
  globals()[f'MSE_svm60_{i}'] = mean_squared_error(data, globals()[f'imputed_svm60_{i}'])
t_end = time.time()
t60_SVM = (t_end- t_start)
# Out:
# Streaming output truncated to the last 5000 lines.
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.986209027295434, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8021757080958132, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9562171764871712, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.8204081891493091, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6534833156993827, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.2699317730680164, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.6769966901607978, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0917531180896969, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6940793817581445, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.2106863608012146, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0009880234900557, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.7159980081532469, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.3437737744924352, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8282274165219228, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7562916790361536, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9541710834136765, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.2061925043299304, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.777485949674829, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.8142768705503887, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.0708131073767282, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8821900225159531, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.962803004217446, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.9537872315136466, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6725324859958244, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.1730054582718505, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0406067012307973, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.3464401145200027, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.093052324064459, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8827852221573949, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0789589452526638, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.1650607946596452, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9537362135628493, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.9706676806769714, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8937683391569262, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.2127226404023252, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.9542400734819019, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.6682323869740125, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.14
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6060455739137796, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.0786019849686381, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.058939730060442, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0056313769025476, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7377853574324078, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0525390073095533, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6438702120484274, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0371346074591665, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6636691940442248, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.9071358494103174, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8156327247404747, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9181347481085291, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.6566829472251747, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7594855838023182, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8009616617725062, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 2.108397773259422, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8622225960492784, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.166171300119899, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8362207745934045, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0011583516474474, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.1338106210575214, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.853848753532612, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.895923930639432, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9211977922134178, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9026796548088356, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.0195273403748182, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8802220957031812, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.9244037485672614, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7208190981007592, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8082859287052262, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.8707184125353429, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.5598480746279826, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.2666985382651204, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.880351858021795, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.9039504053215657, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9701417735685123, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.8044599531674379, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0341596325109164, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5847337230107215, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.8954285303610359, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.18259446184444, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.0372610231536576, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.642668632515524, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.92805617513444, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.2881842173903504, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9331568175295439, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.708576269453884, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.0374536831626884, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8065552680161607, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9720049757117346, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.271673223710219, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9105412145163188, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.0628643310845893, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.9395374227210693, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9995724690385748, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.1981193850261018, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9607918459462361, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7204027785372116, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.689135320327554, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8868217811441168, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.8472867920129108, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.5535216164488626, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.1860004950386784, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.2587121429148382, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0986791477668199, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8566382691418806, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.037752135341111, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9098776628377916, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.7012416301786715, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7267063027519827, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.14
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.886145750878006, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.9541312767114727, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.1440807506107422, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9763310856840866, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.7611688500926288, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.2497348056985196, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.8466438130978569, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7010335733838611, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.710961937036128, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.9844434762949614, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.3734991408664063, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9626282053375439, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.1235601478048967, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0578558337989765, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.781463286391948, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.14
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9398803336359194, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9175741111680527, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.9342977589720638, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0622558211980335, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9302335246693776, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.0163942203390421, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# ...
# [IterativeImputer] Change: 0.9460900569699753, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6435254551644647, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.910287602290861, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.5294689311012206, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.6982817152522642, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.8307539042491694, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6887715410389372, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.005128691524857, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.8944293745989009, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9221328885548274, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6378080905747394, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.9800862532687367, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.213194439068558, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.08
# [IterativeImputer] Change: 1.092349193209393, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.14
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8342433374234384, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6777873109137369, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.1556675160001424, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9470014145902672, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.1621470074841778, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.6735470611757925, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9563695135808592, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7768724003652183, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9398370276663224, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8496610386716652, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.1635742440837964, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.7723455617940216, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.2551307539707084, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.0502275681971627, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9917311637076507, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.2631758172725291, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.933181156066726, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.7969425142549342, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.9481862931276019, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.0054511152002368, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.288887244433032, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 1.1562510716748324, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.8738571406375426, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6082374810701721, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.8188169401090963, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.9049629313680239, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.07
# [IterativeImputer] Change: 0.8173014943560792, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 0.6596696718560393, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.13
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (153, 26)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.06
# [IterativeImputer] Change: 1.2155005387396187, scaled tolerance: 0.274
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.12
# [IterativeImputer] Change: 0.0, scaled tolerance: 0.274
# [IterativeImputer] Early stopping criterion reached.

# %%
t_start = time.time()
mse_svm60_total = 0 
MSE_svm60_1001 = 0
for i in range(1,1001):
  mse_svm60_total = mse_svm60_total + globals()[f'MSE_svm60_{i}']
AMSE_Uric_Acid6_svm = mse_svm60_total/1000
print(f'AMSE_Uric_Acid6_svm = {AMSE_Uric_Acid6_svm}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid6_svm = 0.0033968258477037037
# เวลาที่ใช้ในการประมวลผล 0.001050710678100586 วินาที
# เวลาที่ใช้ในการประมวลผล 1.7511844635009766e-05 นาที

# %% [markdown]
# ## Imputation using the EM

# %% [markdown]
# ### impy.em

# %%
# !pip install impyute
import impyute as impy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: impyute in /usr/local/lib/python3.8/dist-packages (0.0.8)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from impyute) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from impyute) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->impyute) (1.2.0)

# %%
t_start = time.time()
for i in range(1,1001):
  globals()[f'imputed_impy60_{i}'] = impy.em(globals()[f'Uric_Acid6{i}'].values.copy())
  globals()[f'MSE_impy60_{i}'] = mean_squared_error(data, globals()[f'imputed_impy60_{i}'])
t_end = time.time()
t60_EM = (t_end- t_start)

# %%
t_start = time.time()
mse_impy60_total = 0 
MSE_impy60_1001 = 0
for i in range(1,1001):
  mse_impy60_total = mse_impy60_total + globals()[f'MSE_impy60_{i}']
AMSE_Uric_Acid6_impy = mse_impy60_total/1000
print(f'AMSE_Uric_Acid6_impy = {AMSE_Uric_Acid6_impy}')
t_end = time.time()
print(f'เวลาที่ใช้ในการประมวลผล {t_end- t_start} วินาที')
print(f'เวลาที่ใช้ในการประมวลผล {(t_end- t_start)/60} นาที')
# Out:
# AMSE_Uric_Acid6_impy = 0.009785569799044217
# เวลาที่ใช้ในการประมวลผล 0.0011210441589355469 วินาที
# เวลาที่ใช้ในการประมวลผล 1.8684069315592446e-05 นาที

# %% [markdown]
# # AMSE

# %%
amse_value = {'Method':['MEAN','Miss Forest','KNN','MICE-LR','MICE-SVM','EM'],
              '10%':[AMSE_Uric_Acid1_mean,AMSE_Uric_Acid1_mf,AMSE_Uric_Acid1_knn,AMSE_Uric_Acid1_lr,AMSE_Uric_Acid1_svm,AMSE_Uric_Acid1_impy],
      '20%':[AMSE_Uric_Acid2_mean,AMSE_Uric_Acid2_mf,AMSE_Uric_Acid2_knn,AMSE_Uric_Acid2_lr,AMSE_Uric_Acid2_svm,AMSE_Uric_Acid2_impy],
      '30%':[AMSE_Uric_Acid3_mean,AMSE_Uric_Acid3_mf,AMSE_Uric_Acid3_knn,AMSE_Uric_Acid3_lr,AMSE_Uric_Acid3_svm,AMSE_Uric_Acid3_impy],
      '40%':[AMSE_Uric_Acid4_mean,AMSE_Uric_Acid4_mf,AMSE_Uric_Acid4_knn,AMSE_Uric_Acid4_lr,AMSE_Uric_Acid4_svm,AMSE_Uric_Acid4_impy],
      '50%':[AMSE_Uric_Acid5_mean,AMSE_Uric_Acid5_mf,AMSE_Uric_Acid5_knn,AMSE_Uric_Acid5_lr,AMSE_Uric_Acid5_svm,AMSE_Uric_Acid5_impy]
      ,'60%':[AMSE_Uric_Acid6_mean,AMSE_Uric_Acid6_mf,AMSE_Uric_Acid6_knn,AMSE_Uric_Acid6_lr,AMSE_Uric_Acid6_svm,AMSE_Uric_Acid6_impy]}

# %%
data_AMSE = pd.DataFrame.from_dict(amse_value)
data_AMSE
# Out:
#         Method       10%       20%       30%       40%       50%       60%
# 0         MEAN  0.005142  0.005142  0.005142  0.005142  0.005142  0.005142
# 1  Miss Forest  0.002691  0.002691  0.002691  0.002691  0.002691  0.002691
# 2          KNN  0.003561  0.003561  0.003561  0.003561  0.003561  0.003561
# 3      MICE-LR  0.003166  0.003166  0.003166  0.003166  0.003166  0.003166
# 4     MICE-SVM  0.003397  0.003397  0.003397  0.003397  0.003397  0.003397
# 5           EM  0.009786  0.009786  0.009786  0.009786  0.009786  0.009786

# %% [markdown]
# # เวลาทั้งหมดในการรัน

# %% [markdown]
# ## second

# %%
data_t_sec = {'Method':['MEAN','Miss Forest','KNN','MICE-LR','MICE-SVM','EM'],'10%':[t10_MEAN,t10_MF,t10_KNN,t10_LR,t10_SVM,t10_EM],
      '20%':[t20_MEAN,t20_MF,t20_KNN,t20_LR,t20_SVM,t20_EM],'30%':[t30_MEAN,t30_MF,t30_KNN,t30_LR,t30_SVM,t30_EM],'40%':[t40_MEAN,t40_MF,t40_KNN,t40_LR,t40_SVM,t40_EM],
      '50%':[t50_MEAN,t50_MF,t50_KNN,t50_LR,t50_SVM,t50_EM],'60%':[t60_MEAN,t60_MF,t60_KNN,t60_LR,t60_SVM,t60_EM]}

# %%
data_second = pd.DataFrame.from_dict(data_t_sec)
data_second
# Out:
#         Method         10%         20%         30%         40%         50%  \
# 0         MEAN    4.206375    4.196664    4.264201    4.293375    4.315475
# 1  Miss Forest  801.201776  791.625298  787.460768  796.464191  804.381573
# 2          KNN    5.374224    5.178041    5.197508    5.269621    5.324990
# 3      MICE-LR   59.089544   58.385837   59.195011   59.506674   60.169920
# 4     MICE-SVM  128.973541  127.904124  129.297898  129.999404  131.090430
# 5           EM    7.025534    6.844211    6.898383    7.208917    7.031186
#
#           60%
# 0    4.407634
# 1  811.449478
# 2    5.609306
# 3   62.104120
# 4  132.477213
# 5    7.707606

# %% [markdown]
# ## minutes

# %%
data_t_min = {'Method':['MEAN','Miss Forest','KNN','MICE-LR','MICE-SVM','EM'],'10%':[t10_MEAN/60,t10_MF/60,t10_KNN/60,t10_LR/60,t10_SVM/60,t10_EM/60],
      '20%':[t20_MEAN/60,t20_MF/60,t20_KNN/60,t20_LR/60,t20_SVM/60,t20_EM/60],'30%':[t30_MEAN/60,t30_MF/60,t30_KNN/60,t30_LR/60,t30_SVM/60,t30_EM/60]
      ,'40%':[t40_MEAN/60,t40_MF/60,t40_KNN/60,t40_LR/60,t40_SVM/60,t40_EM/60],'50%':[t50_MEAN/60,t50_MF/60,t50_KNN/60,t50_LR/60,t50_SVM/60,t50_EM/60],
      '60%':[t60_MEAN/60,t60_MF/60,t60_KNN/60,t60_LR/60,t60_SVM/60,t60_EM/60]}

# %%
data_minutes = pd.DataFrame.from_dict(data_t_min)
data_minutes
# Out:
#         Method        10%        20%        30%        40%        50%  \
# 0         MEAN   0.070106   0.069944   0.071070   0.071556   0.071925
# 1  Miss Forest  13.353363  13.193755  13.124346  13.274403  13.406360
# 2          KNN   0.089570   0.086301   0.086625   0.087827   0.088750
# 3      MICE-LR   0.984826   0.973097   0.986584   0.991778   1.002832
# 4     MICE-SVM   2.149559   2.131735   2.154965   2.166657   2.184840
# 5           EM   0.117092   0.114070   0.114973   0.120149   0.117186
#
#          60%
# 0   0.073461
# 1  13.524158
# 2   0.093488
# 3   1.035069
# 4   2.207954
# 5   0.128460
